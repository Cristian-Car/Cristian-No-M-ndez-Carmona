# %% [markdown]
# <a href="https://colab.research.google.com/github/Cristian-Car/Cristian-No-M-ndez-Carmona/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Estudiante:
    def __init__(self, nombre, edad, calificacion):
        self.nombre = nombre
        self.edad = edad
        self.calificacion = calificacion

    def mostrar_datos(self):
        print(f"Nombre: {self.nombre}")
        print(f"Edad: {self.edad}")
        print(f"Calificación: {self.calificacion}")
        print("-" * 30)

# Crear dos objetos diferentes
estudiante1 = Estudiante("Ana", 20, 9.5)
estudiante2 = Estudiante("Carlos", 22, 8.7)

# Mostrar la información de cada estudiante
estudiante1.mostrar_datos()
estudiante2.mostrar_datos()
# Out:
# Nombre: Ana
# Edad: 20
# Calificación: 9.5
# ------------------------------
# Nombre: Carlos
# Edad: 22
# Calificación: 8.7
# ------------------------------

# %% [markdown]
# class Estudiante:
#     def __init__(self, nombre, edad, calificacion):
#         self.nombre = nombre
#         self.edad = edad
#         self.calificacion = calificacion
#
#     def mostrar_datos(self):
#         print(f"Nombre: {self.nombre}")
#         print(f"Edad: {self.edad}")
#         print(f"Calificación: {self.calificacion}")
#         print("-" * 30)
#
# # Crear dos objetos diferentes
# estudiante1 = Estudiante("Ana", 20, 9.5)
# estudiante2 = Estudiante("Carlos", 22, 8.7)
#
# # Mostrar la información de cada estudiante
# estudiante1.mostrar_datos()
# estudiante2.mostrar_datos()
